# %%
# %matplotlib inline
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
import pandas as pd
import os
import warnings
warnings.simplefilter('ignore')
import numpy as np
import pickle

# %%
rent = "final.csv"
rent_df = pd.read_csv(rent)
rent_df = rent_df.drop(["Unnamed: 0"], axis = 1)
rent_df.head()
# Out:
#   Property_Code Tenant_Code        Event DateOccurred Unit_Code  DateMoveIn  \
# 0            ce    t0013745  Rent Change   2013-04-30    C05266  2006-11-09
# 1            ce    t0013745  Rent Change   2014-05-31    C05266  2006-11-09
# 2            ce    t0013747  Rent Change   2013-04-30    C05270  2012-07-16
# 3            ce    t0013748  Rent Change   2013-04-30    C05272  2012-09-28
# 4            ce    t0013748  Rent Change   2013-09-30    C05272  2012-09-28
#
#   DateMoveOut   Rent  Vacancy  SQFT  BedRooms  Bathroom  chrent  \
# 0         NaN  870.0        0  1400         3       2.5   870.0
# 1  2015-01-31  896.0        1  1400         3       2.5    26.0
# 2  2013-08-11  770.0        1  1088         2       1.5   770.0
# 3         NaN  770.0        0  1088         2       1.5   770.0
# 4         NaN  800.0        0  1088         2       1.5    30.0
#
#                     LengthStay
# 0                          NaN
# 1  245 days 00:00:00.000000000
# 2  103 days 00:00:00.000000000
# 3                          NaN
# 4                          NaN

# %%
sqft_bins = [0, 600, 1000, 2000]
bin_names = ["small", "medium", "large"]
rent_df["Apt Size"] = pd.cut(rent_df["SQFT"], sqft_bins, labels = bin_names)
indexNames = rent_df[rent_df["Rent"] == rent_df ["chrent"]].index
rent_df.drop(indexNames, inplace = True)
outliers = rent_df[rent_df["chrent"] >= 500].index
rent_df.drop(outliers, inplace = True)
outliers2 = rent_df[rent_df["chrent"] <= -500].index
rent_df.drop(outliers2, inplace = True)
rent_df
# Out:
#      Property_Code Tenant_Code        Event DateOccurred Unit_Code  \
# 1               ce    t0013745  Rent Change   2014-05-31    C05266
# 4               ce    t0013748  Rent Change   2013-09-30    C05272
# 5               ce    t0013748  Rent Change   2014-11-01    C05272
# 9               ce    t0013749  Rent Change   2013-12-31    C05274
# 10              ce    t0013749  Rent Change   2015-03-01    C05274
# 11              ce    t0013749  Rent Change   2016-02-29    C05274
# 12              ce    t0013749  Rent Change   2018-02-28    C05274
# 14              ce    t0013750  Rent Change   2013-06-30    C05276
# 15              ce    t0013750  Rent Change   2014-06-30    C05276
# 16              ce    t0013750  Rent Change   2015-06-30    C05276
# 17              ce    t0013750  Rent Change   2016-06-30    C05276
# 19              ce    t0013751  Rent Change   2013-09-30    C05278
# 22              ce    t0013751  Rent Change   2015-01-01    C05278
# 23              ce    t0013751  Rent Change   2015-06-30    C05278
# 25              ce    t0013752  Rent Change   2014-05-31    C05280
# 26              ce    t0013752  Rent Change   2015-05-31    C05280
# 27              ce    t0013752  Rent Change   2016-05-31    C05280
# 31              ce    t0013755  Rent Change   2013-06-30    C0003A
# 33              ce    t0013756  Rent Change   2013-09-01    C0003B
# 34              ce    t0013756  Rent Change   2014-09-30    C0003B
# 36              ce    t0013757  Rent Change   2013-09-01    C0003C
# 39              ce    t0013759  Rent Change   2013-06-30    C0003E
# 41              ce    t0013760  Rent Change   2013-12-01    C0003F
# 44              ce    t0013762  Rent Change   2014-05-31    C0003H
# 45              ce    t0013762  Rent Change   2015-05-31    C0003H
# 48              ce    t0013764  Rent Change   2013-10-31    C0003K
# 50              ce    t0013765  Rent Change   2013-08-01    C0003L
# 51              ce    t0013765  Rent Change   2014-07-31    C0003L
# 52              ce    t0013765  Rent Change   2014-09-01    C0003L
# 53              ce    t0013765  Rent Change   2015-07-31    C0003L
# ...            ...         ...          ...          ...       ...
# 6624           mpg    t0050622  Rent Change   2018-11-12  2010-04B
# 6625           mpg    t0050773  Rent Change   2018-11-19  2036-06B
# 6626           mpg    t0050791  Rent Change   2018-11-16  2024-09B
# 6627           mpg    t0050791  Rent Change   2018-11-20  1980-07B
# 6628            fh    t0050919  Rent Change   2018-11-21     1064A
# 6629            fh    t0050919  Rent Change   2018-11-25     1064A
# 6630            sh    t0051110  Rent Change   2018-11-23    SH5946
# 6631            sh    t0051110  Rent Change   2018-11-26    SH5901
# 6632            ce    t0051473  Rent Change   2018-11-30    M0002A
# 6633            ce    t0051473  Rent Change   2018-11-30    M0005E
# 6634            ce    t0051586  Rent Change   2018-12-03    C5322J
# 6635            sh    t0052825  Rent Change   2018-12-31  WAIT-3TA
# 6636            sh    t0052825  Rent Change   2019-01-07    TH5979
# 6637           mpg    t0052899  Rent Change   2018-12-31  1978-10B
# 6638           mpg    t0052899  Rent Change   2019-01-09  1978-10B
# 6639           mpg    tl108376  Rent Change   2018-04-05  1986-05B
# 6640           mpg    tl110367  Rent Change   2017-11-15  2006-06C
# 6641           mpg    tl110367  Rent Change   2017-11-15  1968-07C
# 6642           mpg    tl110367  Rent Change   2017-11-27  1968-09B
# 6643            fh    tl115488  Rent Change   2018-02-06     1112A
# 6644           mpg    tl115688  Rent Change   2018-01-30  1968-09C
# 6645           mpg    tl116411  Rent Change   2018-04-21  2030-07A
# 6646            fh    tl117521  Rent Change   2018-02-23     4731A
# 6647            fh    tl117521  Rent Change   2018-03-15     1041B
# 6648            fh    tl117521  Rent Change   2018-04-19     1081B
# 6649            fh    tl117521  Rent Change   2018-04-19     1081B
# 6650           mpg    tl122318  Rent Change   2018-04-16  1968-07B
# 6651           mpg    tl122655  Rent Change   2018-04-17  1966-03B
# 6652           mpg    tl122981  Rent Change   2018-04-20  1968-07B
# 6653            fh    tl127278  Rent Change   2018-06-16    1122AB
#
#       DateMoveIn DateMoveOut    Rent  Vacancy  SQFT  BedRooms  Bathroom  \
# 1     2006-11-09  2015-01-31   896.0        1  1400         3       2.5
# 4     2012-09-28         NaN   800.0        0  1088         2       1.5
# 5     2012-09-28  2015-10-31   824.0        1  1088         2       1.5
# 9     2008-11-26         NaN   915.0        0  1400         3       2.5
# 10    2008-11-26         NaN   924.0        0  1400         3       2.5
# 11    2008-11-26         NaN   970.0        0  1400         3       2.5
# 12    2008-11-26         NaN  1044.0        0  1400         3       2.5
# 14    2001-07-21         NaN   890.0        0  1400         3       2.5
# 15    2001-07-21         NaN   917.0        0  1400         3       2.5
# 16    2001-07-21         NaN   945.0        0  1400         3       2.5
# 17    2001-07-21  2017-06-30   999.0        1  1400         3       2.5
# 19    2011-09-16         NaN   803.0        0  1088         2       1.5
# 22    2011-09-16         NaN   810.0        0  1088         2       1.5
# 12      74.0                          NaN    large
# 14      10.0                          NaN    large
# 15      27.0                          NaN    large
# 16      28.0                          NaN    large
# 17      54.0  365 days 00:00:00.000000000    large
# 19      23.0                          NaN    large
# 22       7.0                          NaN    large
# 23      24.0  110 days 00:00:00.000000000    large
# 25      23.0                          NaN    large
# 26      24.0                          NaN    large
# 27      32.0  365 days 00:00:00.000000000    large
# 31      10.0   31 days 00:00:00.000000000   medium
# 33      30.0                          NaN   medium
# 34      20.0  319 days 00:00:00.000000000   medium
# 36      30.0  364 days 00:00:00.000000000   medium
# 39      10.0  336 days 00:00:00.000000000   medium
# 41      25.0  267 days 00:00:00.000000000   medium
# 44      19.0                          NaN   medium
# 45      20.0  326 days 00:00:00.000000000   medium
# 48      26.0   74 days 00:00:00.000000000   medium
# 50      30.0                          NaN   medium
# 51      20.0                          NaN   medium
# 52      10.0                          NaN   medium
# 53      10.0  366 days 00:00:00.000000000   medium
# ...      ...                          ...      ...
# 6624     0.0                          NaN    large
# 6625     0.0                          NaN    large
# 6626     0.0                          NaN   medium
# 6627   254.0                          NaN    large
# 6628     0.0                          NaN   medium
# 6629   110.0                          NaN   medium
# 6630     0.0                          NaN    large
# 6631   -25.0                          NaN    large
# 6632     0.0                          NaN   medium
# 6633    30.0                          NaN   medium
# 6634     0.0                          NaN   medium
# 6635     0.0                          NaN    large
# 6636    65.0                          NaN    large
# 6637     0.0                          NaN   medium
# 6638   118.0                          NaN   medium
# 6639     0.0                          NaN   medium
# 6640     0.0                          NaN   medium
# 6641    49.0                          NaN   medium
# 6642     0.0  180 days 00:00:00.000000000   medium
# 6643     0.0                          NaN   medium
# 6644     0.0                          NaN   medium
# 6645     0.0                          NaN   medium
# 6646     0.0                          NaN   medium
# 6647    15.0                          NaN   medium
# 6648   135.0                          NaN   medium
# 6649  -150.0                          NaN   medium
# 6650     0.0                          NaN   medium
# 6651     0.0                          NaN    large
# 6652     0.0                          NaN   medium
# 6653     0.0                          NaN   medium
#
# [6215 rows x 15 columns]

# %%
X = rent_df[["Apt Size", "BedRooms", "Bathroom", "chrent", "Property_Code"]]
y = rent_df["Vacancy"]
print(X.shape, y.shape)
# Out:
# (6215, 5) (6215,)

# %%
data = X.copy()

data_binary_encoded = pd.get_dummies(data, columns = ["Apt Size", "Property_Code"])
data_binary_encoded
# Out:
#       BedRooms  Bathroom  chrent  Apt Size_small  Apt Size_medium  \
# 1            3       2.5    26.0               0                0
# 4            2       1.5    30.0               0                0
# 5            2       1.5    24.0               0                0
# 9            3       2.5    35.0               0                0
# 10           3       2.5     9.0               0                0
# 11           3       2.5    46.0               0                0
# 12           3       2.5    74.0               0                0
# 14           3       2.5    10.0               0                0
# 15           3       2.5    27.0               0                0
# 16           3       2.5    28.0               0                0
# 17           3       2.5    54.0               0                0
# 19           2       1.5    23.0               0                0
# 22           2       1.5     7.0               0                0
# 23           2       1.5    24.0               0                0
# 25           2       1.5    23.0               0                0
# 26           2       1.5    24.0               0                0
# 27           2       1.5    32.0               0                0
# 31           2       1.0    10.0               0                1
# 33           2       1.0    30.0               0                1
# 34           2       1.0    20.0               0                1
# 36           2       1.0    30.0               0                1
# 6644               0                 0                 0                  1
# 6645               0                 0                 0                  1
# 6646               0                 0                 1                  0
# 6647               0                 0                 1                  0
# 6648               0                 0                 1                  0
# 6649               0                 0                 1                  0
# 6650               0                 0                 0                  1
# 6651               1                 0                 0                  1
# 6652               0                 0                 0                  1
# 6653               0                 0                 1                  0
#
#       Property_Code_sh
# 1                    0
# 4                    0
# 5                    0
# 9                    0
# 10                   0
# 11                   0
# 12                   0
# 14                   0
# 15                   0
# 16                   0
# 17                   0
# 19                   0
# 22                   0
# 23                   0
# 25                   0
# 26                   0
# 27                   0
# 31                   0
# 33                   0
# 34                   0
# 36                   0
# 39                   0
# 41                   0
# 44                   0
# 45                   0
# 48                   0
# 50                   0
# 51                   0
# 52                   0
# 53                   0
# ...                ...
# 6624                 0
# 6625                 0
# 6626                 0
# 6627                 0
# 6628                 0
# 6629                 0
# 6630                 1
# 6631                 1
# 6632                 0
# 6633                 0
# 6634                 0
# 6635                 1
# 6636                 1
# 6637                 0
# 6638                 0
# 6639                 0
# 6640                 0
# 6641                 0
# 6642                 0
# 6643                 0
# 6644                 0
# 6645                 0
# 6646                 0
# 6647                 0
# 6648                 0
# 6649                 0
# 6650                 0
# 6651                 0
# 6652                 0
# 6653                 0
#
# [6215 rows x 10 columns]

# %%
data_binary_encoded = data_binary_encoded.fillna(0)

# %%
data_binary_encoded.dtypes
# Out:
# BedRooms               int64
# Bathroom             float64
# chrent               float64
# Apt Size_small         uint8
# Apt Size_medium        uint8
# Apt Size_large         uint8
# Property_Code_ce       uint8
# Property_Code_fh       uint8
# Property_Code_mpg      uint8
# Property_Code_sh       uint8
# dtype: object

# %%
data_binary_encoded ["BedRooms"]= data_binary_encoded["BedRooms"].astype(float)
data_binary_encoded ["Apt Size_small"]= data_binary_encoded["Apt Size_small"].astype(float)
data_binary_encoded ["Apt Size_medium"]= data_binary_encoded["Apt Size_medium"].astype(float)
data_binary_encoded ["Apt Size_large"]= data_binary_encoded["Apt Size_large"].astype(float)
data_binary_encoded ["Property_Code_ce"]= data_binary_encoded["Property_Code_ce"].astype(float)
data_binary_encoded ["Property_Code_fh"]= data_binary_encoded["Property_Code_fh"].astype(float)
data_binary_encoded ["Property_Code_mpg"]= data_binary_encoded["Property_Code_mpg"].astype(float)
data_binary_encoded ["Property_Code_sh"]= data_binary_encoded["Property_Code_sh"].astype(float)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical

X_train, X_test, y_train, y_test = train_test_split(data_binary_encoded, y, stratify=y, random_state=42)

label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)
# Out:
# Using TensorFlow backend.

# %%
X_test.shape

# %%
from keras.models import Sequential
from keras.layers import Dense
deep_model = Sequential()

deep_model.add(Dense(units=100, activation='relu', input_dim=10))
deep_model.add(Dense(units=100, activation='relu'))
deep_model.add(Dense(units=2, activation='softmax'))

# %%
deep_model.compile(optimizer='adam',
                   loss='categorical_crossentropy',
                   metrics=['accuracy'])

deep_model.fit(
    X_train,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2
)

# %%
model_loss, model_accuracy = deep_model.evaluate(
    X_test, y_test_categorical, verbose=2)
print(f"Deep Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")

# %%
deep_predictions = deep_model.predict_classes(X_test)
deep_predictor = pd.DataFrame({"Predictions": deep_predictions, "Actual": y_test})
deep_predictor.loc[deep_predictor["Predictions"] == 1, "Predictions"] = "Vacant"
deep_predictor.loc[deep_predictor["Predictions"] == 0, "Predictions"] = "Occupied"
deep_predictor.loc[deep_predictor["Actual"] == 1, "Actual"] = "Vacant"
deep_predictor.loc[deep_predictor["Actual"] == 0, "Actual"] = "Occupied"
deep_predictor

# %%
deep_model.save("logistics_deep_network.h5")

# %%
filename = "logisitic_depp_network.pkl"
list_pickle = open(filename, "wb")
pickle.dump(deep_model, list_pickle)
list_pickle.close()
