# %%
# %matplotlib inline
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
import pandas as pd
import os
import warnings
warnings.simplefilter('ignore')
import numpy as np
import pickle

# %%
rent = "final.csv"
rent_df = pd.read_csv(rent)
rent_df = rent_df.drop(["Unnamed: 0"], axis = 1)
rent_df.head()
# Out:
#   Property_Code Tenant_Code        Event DateOccurred Unit_Code DateMoveIn  \
# 0            ce    t0013745  Rent Change    4/30/2013    C05266  11/9/2006
# 1            ce    t0013745  Rent Change    5/31/2014    C05266  11/9/2006
# 2            ce    t0013747  Rent Change    4/30/2013    C05270  7/16/2012
# 3            ce    t0013748  Rent Change    4/30/2013    C05272  9/28/2012
# 4            ce    t0013748  Rent Change    9/30/2013    C05272  9/28/2012
#
#   DateMoveOut   Rent  Vacancy  SQFT  BedRooms  Bathroom  chrent  \
# 0         NaN  870.0        0  1400         3       2.5   870.0
# 1   1/31/2015  896.0        1  1400         3       2.5    26.0
# 2   8/11/2013  770.0        1  1088         2       1.5   770.0
# 3         NaN  770.0        0  1088         2       1.5   770.0
# 4         NaN  800.0        0  1088         2       1.5    30.0
#
#                     LengthStay
# 0                          NaN
# 1  245 days 00:00:00.000000000
# 2  103 days 00:00:00.000000000
# 3                          NaN
# 4                          NaN

# %%
sqft_bins = [0, 600, 1000, 2000]
bin_names = ["small", "medium", "large"]
rent_df["Apt Size"] = pd.cut(rent_df["SQFT"], sqft_bins, labels = bin_names)
indexNames = rent_df[rent_df["Rent"] == rent_df ["chrent"]].index
rent_df.drop(indexNames, inplace = True)
outliers = rent_df[rent_df["chrent"] >= 500].index
rent_df.drop(outliers, inplace = True)
outliers2 = rent_df[rent_df["chrent"] <= -500].index
rent_df.drop(outliers2, inplace = True)
rent_df
# Out:
#      Property_Code Tenant_Code        Event DateOccurred Unit_Code  \
# 1               ce    t0013745  Rent Change    5/31/2014    C05266
# 4               ce    t0013748  Rent Change    9/30/2013    C05272
# 5               ce    t0013748  Rent Change    11/1/2014    C05272
# 9               ce    t0013749  Rent Change   12/31/2013    C05274
# 10              ce    t0013749  Rent Change     3/1/2015    C05274
# 11              ce    t0013749  Rent Change    2/29/2016    C05274
# 12              ce    t0013749  Rent Change    2/28/2018    C05274
# 14              ce    t0013750  Rent Change    6/30/2013    C05276
# 15              ce    t0013750  Rent Change    6/30/2014    C05276
# 16              ce    t0013750  Rent Change    6/30/2015    C05276
# 17              ce    t0013750  Rent Change    6/30/2016    C05276
# 19              ce    t0013751  Rent Change    9/30/2013    C05278
# 22              ce    t0013751  Rent Change     1/1/2015    C05278
# 23              ce    t0013751  Rent Change    6/30/2015    C05278
# 25              ce    t0013752  Rent Change    5/31/2014    C05280
# 26              ce    t0013752  Rent Change    5/31/2015    C05280
# 27              ce    t0013752  Rent Change    5/31/2016    C05280
# 31              ce    t0013755  Rent Change    6/30/2013    C0003A
# 33              ce    t0013756  Rent Change     9/1/2013    C0003B
# 34              ce    t0013756  Rent Change    9/30/2014    C0003B
# 36              ce    t0013757  Rent Change     9/1/2013    C0003C
# 39              ce    t0013759  Rent Change    6/30/2013    C0003E
# 41              ce    t0013760  Rent Change    12/1/2013    C0003F
# 44              ce    t0013762  Rent Change    5/31/2014    C0003H
# 45              ce    t0013762  Rent Change    5/31/2015    C0003H
# 48              ce    t0013764  Rent Change   10/31/2013    C0003K
# 50              ce    t0013765  Rent Change     8/1/2013    C0003L
# 51              ce    t0013765  Rent Change    7/31/2014    C0003L
# 52              ce    t0013765  Rent Change     9/1/2014    C0003L
# 53              ce    t0013765  Rent Change    7/31/2015    C0003L
# ...            ...         ...          ...          ...       ...
# 6619           mpg    t0049401  Rent Change   10/20/2018  1998-02B
# 6620            sh    t0049448  Rent Change   10/26/2018   FT5892C
# 6621            fh    t0049885  Rent Change   10/29/2018     1068B
# 6622            fh    t0050170  Rent Change    11/6/2018     1081A
# 6623           mpg    t0050472  Rent Change   11/12/2018  2032-03B
# 6624           mpg    t0050622  Rent Change   11/12/2018  2010-04B
# 6625           mpg    t0050773  Rent Change   11/19/2018  2036-06B
# 6626           mpg    t0050791  Rent Change   11/16/2018  2024-09B
# 6628            fh    t0050919  Rent Change   11/21/2018     1064A
# 6630            sh    t0051110  Rent Change   11/23/2018    SH5946
# 6631            sh    t0051110  Rent Change   11/26/2018    SH5901
# 6632            ce    t0051473  Rent Change   11/30/2018    M0002A
# 6633            ce    t0051473  Rent Change   11/30/2018    M0005E
# 6634            ce    t0051586  Rent Change    12/3/2018    C5322J
# 6635            sh    t0052825  Rent Change   12/31/2018  WAIT-3TA
# 6636            sh    t0052825  Rent Change     1/7/2019    TH5979
# 6637           mpg    t0052899  Rent Change   12/31/2018  1978-10B
# 6639           mpg    tl108376  Rent Change     4/5/2018  1986-05B
# 6640           mpg    tl110367  Rent Change   11/15/2017  2006-06C
# 6641           mpg    tl110367  Rent Change   11/15/2017  1968-07C
# 6642           mpg    tl110367  Rent Change   11/27/2017  1968-09B
# 6643            fh    tl115488  Rent Change     2/6/2018     1112A
# 6644           mpg    tl115688  Rent Change    1/30/2018  1968-09C
# 6645           mpg    tl116411  Rent Change    4/21/2018  2030-07A
# 6646            fh    tl117521  Rent Change    2/23/2018     4731A
# 6647            fh    tl117521  Rent Change    3/15/2018     1041B
# 6650           mpg    tl122318  Rent Change    4/16/2018  1968-07B
# 6651           mpg    tl122655  Rent Change    4/17/2018  1966-03B
# 6652           mpg    tl122981  Rent Change    4/20/2018  1968-07B
# 6653            fh    tl127278  Rent Change    6/16/2018    1122AB
#
#       DateMoveIn DateMoveOut    Rent  Vacancy  SQFT  BedRooms  Bathroom  \
# 1      11/9/2006   1/31/2015   896.0        1  1400         3       2.5
# 4      9/28/2012         NaN   800.0        0  1088         2       1.5
# 5      9/28/2012  10/31/2015   824.0        1  1088         2       1.5
# 9     11/26/2008         NaN   915.0        0  1400         3       2.5
# 10    11/26/2008         NaN   924.0        0  1400         3       2.5
# 11    11/26/2008         NaN   970.0        0  1400         3       2.5
# 12    11/26/2008         NaN  1044.0        0  1400         3       2.5
# 14     7/21/2001         NaN   890.0        0  1400         3       2.5
# 15     7/21/2001         NaN   917.0        0  1400         3       2.5
# 16     7/21/2001         NaN   945.0        0  1400         3       2.5
# 17     7/21/2001   6/30/2017   999.0        1  1400         3       2.5
# 4       30.0                          NaN    large
# 5       24.0  364 days 00:00:00.000000000    large
# 9       35.0                          NaN    large
# 10       9.0                          NaN    large
# 11      46.0                          NaN    large
# 12      74.0                          NaN    large
# 14      10.0                          NaN    large
# 15      27.0                          NaN    large
# 16      28.0                          NaN    large
# 17      54.0  365 days 00:00:00.000000000    large
# 19      23.0                          NaN    large
# 22       7.0                          NaN    large
# 23      24.0  110 days 00:00:00.000000000    large
# 25      23.0                          NaN    large
# 26      24.0                          NaN    large
# 27      32.0  365 days 00:00:00.000000000    large
# 31      10.0   31 days 00:00:00.000000000   medium
# 33      30.0                          NaN   medium
# 34      20.0  319 days 00:00:00.000000000   medium
# 36      30.0  364 days 00:00:00.000000000   medium
# 39      10.0  336 days 00:00:00.000000000   medium
# 41      25.0  267 days 00:00:00.000000000   medium
# 44      19.0                          NaN   medium
# 45      20.0  326 days 00:00:00.000000000   medium
# 48      26.0   74 days 00:00:00.000000000   medium
# 50      30.0                          NaN   medium
# 51      20.0                          NaN   medium
# 52      10.0                          NaN   medium
# 53      10.0  366 days 00:00:00.000000000   medium
# ...      ...                          ...      ...
# 6619     0.0                          NaN   medium
# 6620     0.0                          NaN   medium
# 6621     0.0                          NaN   medium
# 6622     0.0                          NaN   medium
# 6623     0.0                          NaN    large
# 6624     0.0                          NaN    large
# 6625     0.0                          NaN    large
# 6626     0.0                          NaN   medium
# 6628     0.0                          NaN   medium
# 6630     0.0                          NaN    large
# 6631   -25.0                          NaN    large
# 6632     0.0                          NaN   medium
# 6633    30.0                          NaN   medium
# 6634     0.0                          NaN   medium
# 6635     0.0                          NaN    large
# 6636    65.0                          NaN    large
# 6637     0.0                          NaN   medium
# 6639     0.0                          NaN   medium
# 6640     0.0                          NaN   medium
# 6641    49.0                          NaN   medium
# 6642     0.0  180 days 00:00:00.000000000   medium
# 6643     0.0                          NaN   medium
# 6644     0.0                          NaN   medium
# 6645     0.0                          NaN   medium
# 6646     0.0                          NaN   medium
# 6647    15.0                          NaN   medium
# 6650     0.0                          NaN   medium
# 6651     0.0                          NaN    large
# 6652     0.0                          NaN   medium
# 6653     0.0                          NaN   medium
#
# [5950 rows x 15 columns]

# %%
X = rent_df[["Apt Size", "BedRooms", "Bathroom", "chrent", "Property_Code"]]
y = rent_df["Vacancy"]
print(X.shape, y.shape)
# Out:
# (5950, 5) (5950,)

# %%
data = X.copy()

data_binary_encoded = pd.get_dummies(data, columns = ["Apt Size", "Property_Code"])
data_binary_encoded
# Out:
#       BedRooms  Bathroom  chrent  Apt Size_small  Apt Size_medium  \
# 1            3       2.5    26.0               0                0
# 4            2       1.5    30.0               0                0
# 5            2       1.5    24.0               0                0
# 9            3       2.5    35.0               0                0
# 10           3       2.5     9.0               0                0
# 11           3       2.5    46.0               0                0
# 12           3       2.5    74.0               0                0
# 14           3       2.5    10.0               0                0
# 15           3       2.5    27.0               0                0
# 16           3       2.5    28.0               0                0
# 17           3       2.5    54.0               0                0
# 19           2       1.5    23.0               0                0
# 22           2       1.5     7.0               0                0
# 23           2       1.5    24.0               0                0
# 25           2       1.5    23.0               0                0
# 6632               0                 1                 0                  0
# 6633               0                 1                 0                  0
# 6634               0                 1                 0                  0
# 6635               1                 0                 0                  0
# 6636               1                 0                 0                  0
# 6637               0                 0                 0                  1
# 6639               0                 0                 0                  1
# 6640               0                 0                 0                  1
# 6641               0                 0                 0                  1
# 6642               0                 0                 0                  1
# 6643               0                 0                 1                  0
# 6644               0                 0                 0                  1
# 6645               0                 0                 0                  1
# 6646               0                 0                 1                  0
# 6647               0                 0                 1                  0
# 6650               0                 0                 0                  1
# 6651               1                 0                 0                  1
# 6652               0                 0                 0                  1
# 6653               0                 0                 1                  0
#
#       Property_Code_sh
# 1                    0
# 4                    0
# 5                    0
# 9                    0
# 10                   0
# 11                   0
# 12                   0
# 14                   0
# 15                   0
# 16                   0
# 17                   0
# 19                   0
# 22                   0
# 23                   0
# 25                   0
# 26                   0
# 27                   0
# 31                   0
# 33                   0
# 34                   0
# 36                   0
# 39                   0
# 41                   0
# 44                   0
# 45                   0
# 48                   0
# 50                   0
# 51                   0
# 52                   0
# 53                   0
# ...                ...
# 6619                 0
# 6620                 1
# 6621                 0
# 6622                 0
# 6623                 0
# 6624                 0
# 6625                 0
# 6626                 0
# 6628                 0
# 6630                 1
# 6631                 1
# 6632                 0
# 6633                 0
# 6634                 0
# 6635                 1
# 6636                 1
# 6637                 0
# 6639                 0
# 6640                 0
# 6641                 0
# 6642                 0
# 6643                 0
# 6644                 0
# 6645                 0
# 6646                 0
# 6647                 0
# 6650                 0
# 6651                 0
# 6652                 0
# 6653                 0
#
# [5950 rows x 10 columns]

# %%
data_binary_encoded = data_binary_encoded.fillna(0)

# %%
data_binary_encoded.dtypes
# Out:
# BedRooms               int64
# Bathroom             float64
# chrent               float64
# Apt Size_small         uint8
# Apt Size_medium        uint8
# Apt Size_large         uint8
# Property_Code_ce       uint8
# Property_Code_fh       uint8
# Property_Code_mpg      uint8
# Property_Code_sh       uint8
# dtype: object

# %%
data_binary_encoded ["BedRooms"]= data_binary_encoded["BedRooms"].astype(float)
data_binary_encoded ["Apt Size_small"]= data_binary_encoded["Apt Size_small"].astype(float)
data_binary_encoded ["Apt Size_medium"]= data_binary_encoded["Apt Size_medium"].astype(float)
data_binary_encoded ["Apt Size_large"]= data_binary_encoded["Apt Size_large"].astype(float)
data_binary_encoded ["Property_Code_ce"]= data_binary_encoded["Property_Code_ce"].astype(float)
data_binary_encoded ["Property_Code_fh"]= data_binary_encoded["Property_Code_fh"].astype(float)
data_binary_encoded ["Property_Code_mpg"]= data_binary_encoded["Property_Code_mpg"].astype(float)
data_binary_encoded ["Property_Code_sh"]= data_binary_encoded["Property_Code_sh"].astype(float)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical

X_train, X_test, y_train, y_test = train_test_split(data_binary_encoded, y, stratify=y, random_state=42)

label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %%
X_test.shape
# Out:
# (1488, 10)

# %%
from keras.models import Sequential
from keras.layers import Dense
deep_model = Sequential()

deep_model.add(Dense(units=100, activation='relu', input_dim=10))
deep_model.add(Dense(units=100, activation='relu'))
deep_model.add(Dense(units=2, activation='softmax'))

# %%
deep_model.compile(optimizer='adam',
                   loss='categorical_crossentropy',
                   metrics=['accuracy'])

deep_model.fit(
    X_train,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/100
#  - 0s - loss: 0.6183 - acc: 0.7344
# Epoch 2/100
#  - 0s - loss: 0.5824 - acc: 0.7398
# Epoch 3/100
#  - 0s - loss: 0.5717 - acc: 0.7400
# Epoch 4/100
#  - 0s - loss: 0.5671 - acc: 0.7423
# Epoch 5/100
#  - 0s - loss: 0.5666 - acc: 0.7416
# Epoch 6/100
#  - 0s - loss: 0.5610 - acc: 0.7456
# Epoch 7/100
#  - 0s - loss: 0.5617 - acc: 0.7450
# Epoch 8/100
#  - 0s - loss: 0.5604 - acc: 0.7445
# Epoch 9/100
#  - 0s - loss: 0.5569 - acc: 0.7470
# Epoch 10/100
#  - 0s - loss: 0.5596 - acc: 0.7450
# Epoch 11/100
#  - 0s - loss: 0.5579 - acc: 0.7454
# Epoch 12/100
#  - 0s - loss: 0.5590 - acc: 0.7414
# Epoch 13/100
#  - 0s - loss: 0.5542 - acc: 0.7456
# Epoch 14/100
#  - 0s - loss: 0.5545 - acc: 0.7445
# Epoch 15/100
#  - 0s - loss: 0.5518 - acc: 0.7474
# Epoch 16/100
#  - 0s - loss: 0.5507 - acc: 0.7474
# Epoch 17/100
#  - 0s - loss: 0.5537 - acc: 0.7454
# Epoch 18/100
#  - 0s - loss: 0.5521 - acc: 0.7483
# Epoch 19/100
#  - 0s - loss: 0.5513 - acc: 0.7485
# Epoch 20/100
#  - 0s - loss: 0.5472 - acc: 0.7485
# Epoch 21/100
#  - 0s - loss: 0.5527 - acc: 0.7465
# Epoch 22/100
#  - 0s - loss: 0.5478 - acc: 0.7485
# Epoch 23/100
#  - 0s - loss: 0.5484 - acc: 0.7485
# Epoch 24/100
#  - 0s - loss: 0.5505 - acc: 0.7483
# Epoch 25/100
#  - 0s - loss: 0.5478 - acc: 0.7479
# Epoch 26/100
#  - 0s - loss: 0.5492 - acc: 0.7485
# Epoch 27/100
#  - 0s - loss: 0.5489 - acc: 0.7472
# Epoch 28/100
#  - 0s - loss: 0.5495 - acc: 0.7474
# Epoch 29/100
#  - 0s - loss: 0.5472 - acc: 0.7485
# Epoch 30/100
#  - 0s - loss: 0.5467 - acc: 0.7481
# Epoch 31/100
#  - 0s - loss: 0.5466 - acc: 0.7485
# Epoch 32/100
#  - 0s - loss: 0.5474 - acc: 0.7485
# Epoch 33/100
#  - 0s - loss: 0.5464 - acc: 0.7485
# Epoch 34/100
#  - 0s - loss: 0.5464 - acc: 0.7485
# Epoch 35/100
#  - 0s - loss: 0.5473 - acc: 0.7485
# Epoch 36/100
#  - 0s - loss: 0.5473 - acc: 0.7485
# Epoch 37/100
#  - 0s - loss: 0.5481 - acc: 0.7481
# Epoch 38/100
#  - 0s - loss: 0.5456 - acc: 0.7485
# Epoch 39/100
#  - 0s - loss: 0.5467 - acc: 0.7485
# Epoch 40/100
#  - 0s - loss: 0.5454 - acc: 0.7485
# Epoch 41/100
#  - 0s - loss: 0.5465 - acc: 0.7485
# Epoch 42/100
#  - 0s - loss: 0.5469 - acc: 0.7483
# Epoch 43/100
#  - 0s - loss: 0.5437 - acc: 0.7485
# Epoch 44/100
#  - 0s - loss: 0.5457 - acc: 0.7485
# Epoch 45/100
#  - 0s - loss: 0.5455 - acc: 0.7485
# Epoch 46/100
#  - 0s - loss: 0.5448 - acc: 0.7485
# Epoch 47/100
#  - 0s - loss: 0.5459 - acc: 0.7485
# Epoch 48/100
#  - 0s - loss: 0.5455 - acc: 0.7485
# Epoch 49/100
#  - 0s - loss: 0.5449 - acc: 0.7485
# Epoch 50/100
#  - 0s - loss: 0.5447 - acc: 0.7488
# Epoch 51/100
#  - 0s - loss: 0.5453 - acc: 0.7485
# Epoch 52/100
#  - 0s - loss: 0.5447 - acc: 0.7490
# Epoch 53/100
#  - 0s - loss: 0.5447 - acc: 0.7488
# Epoch 54/100
#  - 0s - loss: 0.5443 - acc: 0.7490
# Epoch 55/100
#  - 0s - loss: 0.5445 - acc: 0.7490
# Epoch 56/100
#  - 0s - loss: 0.5440 - acc: 0.7492
# Epoch 57/100
#  - 0s - loss: 0.5437 - acc: 0.7492
# Epoch 58/100
#  - 0s - loss: 0.5434 - acc: 0.7490
# Epoch 59/100
#  - 0s - loss: 0.5434 - acc: 0.7492
# Epoch 60/100
#  - 0s - loss: 0.5442 - acc: 0.7494
# Epoch 61/100
#  - 0s - loss: 0.5435 - acc: 0.7494
# Epoch 62/100
#  - 0s - loss: 0.5441 - acc: 0.7492
# Epoch 63/100
#  - 0s - loss: 0.5441 - acc: 0.7490
# Epoch 64/100
#  - 0s - loss: 0.5438 - acc: 0.7494
# Epoch 65/100
#  - 0s - loss: 0.5438 - acc: 0.7490
# Epoch 66/100
#  - 0s - loss: 0.5428 - acc: 0.7494
# Epoch 67/100
#  - 0s - loss: 0.5450 - acc: 0.7490
# Epoch 68/100
#  - 0s - loss: 0.5429 - acc: 0.7492
# Epoch 69/100
#  - 0s - loss: 0.5428 - acc: 0.7492
# Epoch 70/100
#  - 0s - loss: 0.5431 - acc: 0.7492
# Epoch 71/100
#  - 0s - loss: 0.5425 - acc: 0.7494
# Epoch 72/100
#  - 0s - loss: 0.5424 - acc: 0.7497
# Epoch 73/100
#  - 0s - loss: 0.5423 - acc: 0.7497
# Epoch 74/100
#  - 0s - loss: 0.5424 - acc: 0.7492
# Epoch 75/100
#  - 0s - loss: 0.5420 - acc: 0.7492
# Epoch 76/100
#  - 0s - loss: 0.5422 - acc: 0.7492
# Epoch 77/100
#  - 0s - loss: 0.5446 - acc: 0.7492
# Epoch 78/100
#  - 0s - loss: 0.5418 - acc: 0.7497
# Epoch 79/100
#  - 0s - loss: 0.5413 - acc: 0.7494
# Epoch 80/100
#  - 0s - loss: 0.5416 - acc: 0.7492
# Epoch 81/100
#  - 0s - loss: 0.5420 - acc: 0.7494
# Epoch 82/100
#  - 0s - loss: 0.5418 - acc: 0.7492
# Epoch 83/100
#  - 0s - loss: 0.5406 - acc: 0.7492
# Epoch 84/100
#  - 0s - loss: 0.5416 - acc: 0.7497
# Epoch 85/100
#  - 0s - loss: 0.5417 - acc: 0.7494
# Epoch 86/100
#  - 0s - loss: 0.5417 - acc: 0.7497
# Epoch 87/100
#  - 0s - loss: 0.5404 - acc: 0.7494
# Epoch 88/100
#  - 0s - loss: 0.5420 - acc: 0.7494
# Epoch 89/100
#  - 0s - loss: 0.5410 - acc: 0.7494
# Epoch 90/100
#  - 0s - loss: 0.5412 - acc: 0.7492
# Epoch 91/100
#  - 0s - loss: 0.5399 - acc: 0.7494
# Epoch 92/100
#  - 0s - loss: 0.5407 - acc: 0.7492
# Epoch 93/100
#  - 0s - loss: 0.5409 - acc: 0.7494
# Epoch 94/100
#  - 0s - loss: 0.5396 - acc: 0.7494
# Epoch 95/100
#  - 0s - loss: 0.5430 - acc: 0.7497
# Epoch 96/100
#  - 0s - loss: 0.5420 - acc: 0.7490
# Epoch 97/100
#  - 0s - loss: 0.5409 - acc: 0.7497
# Epoch 98/100
#  - 0s - loss: 0.5409 - acc: 0.7497
# Epoch 99/100
#  - 0s - loss: 0.5410 - acc: 0.7497
# Epoch 100/100
#  - 0s - loss: 0.5401 - acc: 0.7497

# %%
model_loss, model_accuracy = deep_model.evaluate(
    X_test, y_test_categorical, verbose=2)
print(f"Deep Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Deep Neural Network - Loss: 0.5475274285962505, Accuracy: 0.7473118279569892

# %%
deep_predictions = deep_model.predict_classes(X_test)
deep_predictor = pd.DataFrame({"Predictions": deep_predictions, "Actual": y_test})
deep_predictor.loc[deep_predictor["Predictions"] == 1, "Predictions"] = "Vacant"
deep_predictor.loc[deep_predictor["Predictions"] == 0, "Predictions"] = "Occupied"
deep_predictor.loc[deep_predictor["Actual"] == 1, "Actual"] = "Vacant"
deep_predictor.loc[deep_predictor["Actual"] == 0, "Actual"] = "Occupied"
deep_predictor
# Out:
#      Predictions    Actual
# 4743    Occupied    Vacant
# 6500    Occupied  Occupied
# 2414    Occupied    Vacant
# 5931    Occupied  Occupied
# 844     Occupied  Occupied
# 2777    Occupied  Occupied
# 6036    Occupied  Occupied
# 3137    Occupied  Occupied
# 1334    Occupied  Occupied
# 1692    Occupied  Occupied
# 5177    Occupied  Occupied
# 1561    Occupied  Occupied
# 1723    Occupied  Occupied
# 3218    Occupied    Vacant
# 5235    Occupied    Vacant
# 2117    Occupied  Occupied
# 6106    Occupied  Occupied
# 3537    Occupied    Vacant
# 5842    Occupied    Vacant
# 3492    Occupied  Occupied
# 6160    Occupied  Occupied
# 1739    Occupied  Occupied
# 4935    Occupied  Occupied
# 1752    Occupied  Occupied
# 2722    Occupied  Occupied
# 3402    Occupied    Vacant
# 3669    Occupied  Occupied
# 4189    Occupied  Occupied
# 6435    Occupied  Occupied
# 4880    Occupied  Occupied
# ...          ...       ...
# 5422    Occupied  Occupied
# 3790    Occupied  Occupied
# 5159    Occupied  Occupied
# 4821    Occupied  Occupied
# 1783    Occupied    Vacant
# 3962    Occupied    Vacant
# 2217    Occupied  Occupied
# 2519    Occupied    Vacant
# 2236    Occupied  Occupied
# 5587    Occupied  Occupied
# 126     Occupied  Occupied
# 6299    Occupied  Occupied
# 1292    Occupied  Occupied
# 120     Occupied  Occupied
# 4222    Occupied    Vacant
# 1373    Occupied  Occupied
# 442     Occupied  Occupied
# 3371    Occupied  Occupied
# 405     Occupied  Occupied
# 357     Occupied  Occupied
# 2166    Occupied    Vacant
# 2623    Occupied    Vacant
# 4246    Occupied  Occupied
# 1452    Occupied    Vacant
# 1481    Occupied  Occupied
# 4602    Occupied    Vacant
# 6602    Occupied  Occupied
# 1163    Occupied  Occupied
# 3093    Occupied  Occupied
# 4088    Occupied  Occupied
#
# [1488 rows x 2 columns]

# %%
deep_model.save("logistics_deep_network.h5")

# %%
filename = "logisitic_depp_network.pkl"
list_pickle = open(filename, "wb")
pickle.dump(deep_model, list_pickle)
list_pickle.close()
