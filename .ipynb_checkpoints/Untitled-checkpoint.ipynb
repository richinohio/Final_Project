# %%
import os 
import pandas as pd

# %%
filepath = os.path.join("Tenant_History.csv")
df = pd.read_csv(filepath, skiprows=1)
df.head(100)
# Out:
#    ResTenantHistory       Unnamed: 1  Unnamed: 2   Unnamed: 3  \
# 0     Property_Code  Ref_Property_ID        Date  Tenant_Code
# 1                sh              NaN  11/18/2016     t0031357
# 2                ce              NaN  11/22/2016     t0031261
# 3                ce              NaN  11/18/2016     t0031367
# 4                ce              NaN  11/18/2016     t0031350
# 5                sh              NaN  11/22/2016     t0031408
# 6                ce              NaN  11/22/2016     t0030981
# 7                ce              NaN  11/22/2016     t0031409
# 8                ce              NaN  11/22/2016     t0031409
# 9                ce              NaN  11/22/2016     t0031409
# 10               ce              NaN  11/22/2016     t0031352
# 11               sh              NaN  11/23/2016     t0031354
# 12               sh              NaN  11/20/2016     t0031354
# 13               sh              NaN  11/22/2016     t0031354
# ...

# %%
df.groupby("Unit_Code").count()
# Out:
#              Unit_Code  Ref_Unit_Id  Property_Code  Ref_Property_ID  \
# RDBasicRent
# 0                11843            0          11843                0
#
#              Record_Type   Date   Rent  Deposit   Sqft  FSetAside  \
# RDBasicRent
# 0                  11843  11843  11843    11843  11843      11843
#
#              UtilityAllowance  ContractRent  RoomId  BedId  NewRentsId
# RDBasicRent
# 0                       11843         11843       0      0           0
